# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size= 2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

#Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    if i % 50 == 0 and i >= 50:
        set_count +=1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city
    city_url = url +"&q=" + city.replace(" ","+")
    # Log the URL, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Increase record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        #Append the city information into city_data list
        city_data.append({"City" : city.title(),
                         "Country" : city_country,
                         "Lat" : city_lat,
                         "Lng" :city_lng,
                         "Max Temp" : city_max_temp,
                         "Humidity" : city_humidity,
                         "Cloudiness" : city_clouds,
                         "Wind Speed" : city_wind,
                         "Current Description" : city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        continue

#Indicate that data lodaing is complete
print("------------------------")
print(" Data Retrieval Complete ")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | sawakin
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | pacific grove
# Processing Record 8 of Set 1 | ramgarh
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | atikokan
# Processing Record 12 of Set 1 | balimo
# 'coord'
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | isla vista
# Processing Record 16 of Set 1 | cockburn town
# Processing Record 17 of Set 1 | porosozero
# Processing Record 18 of Set 1 | santa maria
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | amos
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | sur
# Processing Record 25 of Set 1 | camargo
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | rawson
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | egvekinot
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | myrtle beach
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | kachikau
# 'coord'
# Processing Record 38 of Set 1 | taolanaro
# 'coord'
# Processing Record 39 of Set 1 | lodja
# Processing Record 40 of Set 1 | padang
# Processing Record 41 of Set 1 | halifax
# Processing Record 42 of Set 1 | belushya guba
# 'coord'
# Processing Record 43 of Set 1 | beyneu
# Processing Record 44 of Set 1 | malartic
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | quatre cocos
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | barentsburg
# 'coord'
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | plouzane
# Processing Record 2 of Set 2 | kyra
# Processing Record 3 of Set 2 | otjiwarongo
# Processing Record 4 of Set 2 | leh
# Processing Record 5 of Set 2 | ketchikan
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | plettenberg bay
# Processing Record 8 of Set 2 | illoqqortoormiut
# 'coord'
# Processing Record 9 of Set 2 | margate
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | mys shmidta
# 'coord'
# Processing Record 14 of Set 2 | meulaboh
# Processing Record 15 of Set 2 | arman
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | cheuskiny
# 'coord'
# Processing Record 18 of Set 2 | pangnirtung
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | ponta delgada
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | longlac
# 'coord'
# Processing Record 26 of Set 2 | sokoni
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | leshukonskoye
# Processing Record 29 of Set 2 | chagda
# 'coord'
# Processing Record 30 of Set 2 | turukhansk
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | tidore
# 'coord'
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | aykhal
# Processing Record 35 of Set 2 | kahului
# Processing Record 36 of Set 2 | kasongo-lunda
# Processing Record 37 of Set 2 | babanusah
# 'coord'
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | borskoye
# Processing Record 43 of Set 2 | smolyaninovo
# Processing Record 44 of Set 2 | ayagoz
# Processing Record 45 of Set 2 | hasaki
# Processing Record 46 of Set 2 | asau
# Processing Record 47 of Set 2 | saleaula
# 'coord'
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | piney green
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | jiddah
# 'coord'
# Processing Record 4 of Set 3 | la ronge
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | sanary-sur-mer
# Processing Record 7 of Set 3 | celestun
# Processing Record 8 of Set 3 | taoudenni
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | morro bay
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | canico
# Processing Record 13 of Set 3 | srednekolymsk
# Processing Record 14 of Set 3 | nannilam
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | olinda
# Processing Record 17 of Set 3 | orapa
# Processing Record 18 of Set 3 | guarapari
# Processing Record 19 of Set 3 | lufilufi
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | inhambane
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | deputatskiy
# Processing Record 24 of Set 3 | rungata
# 'coord'
# Processing Record 25 of Set 3 | maltahohe
# Processing Record 26 of Set 3 | porbandar
# Processing Record 27 of Set 3 | barguzin
# Processing Record 28 of Set 3 | rio grande
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | chak
# Processing Record 33 of Set 3 | zhigansk
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | daru
# Processing Record 36 of Set 3 | buzmeyin
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | nueve de julio
# Processing Record 40 of Set 3 | sorland
# Processing Record 41 of Set 3 | pinega
# Processing Record 42 of Set 3 | solwezi
# Processing Record 43 of Set 3 | nuuk
# Processing Record 44 of Set 3 | yar-sale
# Processing Record 45 of Set 3 | krasnoselkup
# Processing Record 46 of Set 3 | kapit
# Processing Record 47 of Set 3 | moba
# Processing Record 48 of Set 3 | laje
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | nguiu
# 'coord'
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | tsihombe
# 'coord'
# Processing Record 3 of Set 4 | weiser
# Processing Record 4 of Set 4 | cherskiy
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | buritis
# Processing Record 7 of Set 4 | salalah
# Processing Record 8 of Set 4 | bogorodskoye
# Processing Record 9 of Set 4 | palu
# Processing Record 10 of Set 4 | aklavik
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | odweyne
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | katete
# Processing Record 15 of Set 4 | karamea
# 'coord'
# Processing Record 16 of Set 4 | hami
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | bredasdorp
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | matagami
# Processing Record 21 of Set 4 | severomuysk
# Processing Record 22 of Set 4 | tiksi
# Processing Record 23 of Set 4 | karaul
# 'coord'
# Processing Record 24 of Set 4 | yumen
# Processing Record 25 of Set 4 | barbar
# 'coord'
# Processing Record 26 of Set 4 | saint-augustin
# Processing Record 27 of Set 4 | karratha
# Processing Record 28 of Set 4 | waingapu
# Processing Record 29 of Set 4 | robstown
# Processing Record 30 of Set 4 | acapulco
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | gigmoto
# Processing Record 33 of Set 4 | kalianget
# Processing Record 34 of Set 4 | almaznyy
# Processing Record 35 of Set 4 | nhulunbuy
# Processing Record 36 of Set 4 | lewistown
# Processing Record 37 of Set 4 | wahran
# 'coord'
# Processing Record 38 of Set 4 | puerto del rosario
# Processing Record 39 of Set 4 | lagos
# Processing Record 40 of Set 4 | ubatuba
# Processing Record 41 of Set 4 | vaitupu
# 'coord'
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | le vauclin
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | isiro
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | sechura
# Processing Record 48 of Set 4 | micheweni
# Processing Record 49 of Set 4 | nador
# Processing Record 50 of Set 4 | urumqi
# Processing Record 1 of Set 5 | suez
# Processing Record 2 of Set 5 | yantzaza
# Processing Record 3 of Set 5 | dali
# Processing Record 4 of Set 5 | shaowu
# Processing Record 5 of Set 5 | kudahuvadhoo
# Processing Record 6 of Set 5 | male
# Processing Record 7 of Set 5 | sampit
# Processing Record 8 of Set 5 | koungou
# Processing Record 9 of Set 5 | port blair
# Processing Record 10 of Set 5 | roald
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | chongwe
# Processing Record 13 of Set 5 | jvari
# Processing Record 14 of Set 5 | kodino
# Processing Record 15 of Set 5 | murgab
# Processing Record 16 of Set 5 | katangli
# Processing Record 17 of Set 5 | ottawa
# Processing Record 18 of Set 5 | lewisporte
# Processing Record 19 of Set 5 | sentyabrskiy
# 'coord'
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | ust-kamchatsk
# 'coord'
# Processing Record 22 of Set 5 | ambon
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | najran
# Processing Record 25 of Set 5 | kirkenaer
# Processing Record 26 of Set 5 | mazagao
# Processing Record 27 of Set 5 | anadyr
# Processing Record 28 of Set 5 | morondava
# Processing Record 29 of Set 5 | rolim de moura
# 'coord'
# Processing Record 30 of Set 5 | husavik
# Processing Record 31 of Set 5 | komsomolsk
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | marcona
# 'coord'
# Processing Record 34 of Set 5 | garowe
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | camana
# Processing Record 37 of Set 5 | luderitz
# Processing Record 38 of Set 5 | gizo
# Processing Record 39 of Set 5 | ust-tsilma
# Processing Record 40 of Set 5 | nizhneyansk
# 'coord'
# Processing Record 41 of Set 5 | sinnamary
# Processing Record 42 of Set 5 | san carlos de bariloche
# Processing Record 43 of Set 5 | bacuit
# 'coord'
# Processing Record 44 of Set 5 | grand river south east
# 'coord'
# Processing Record 45 of Set 5 | malpe
# Processing Record 46 of Set 5 | tumannyy
# 'coord'
# Processing Record 47 of Set 5 | belyy yar
# Processing Record 48 of Set 5 | port shepstone
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | bilma
# Processing Record 1 of Set 6 | houma
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | sao geraldo do araguaia
# Processing Record 4 of Set 6 | anaimalai
# Processing Record 5 of Set 6 | amderma
# 'coord'
# Processing Record 6 of Set 6 | esperance
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | butaritari
# Processing Record 9 of Set 6 | caxito
# Processing Record 10 of Set 6 | chokurdakh
# Processing Record 11 of Set 6 | khani
# Processing Record 12 of Set 6 | ler
# Processing Record 13 of Set 6 | san policarpo
# Processing Record 14 of Set 6 | straumen
# Processing Record 15 of Set 6 | big spring
# Processing Record 16 of Set 6 | rosetown
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | tura
# Processing Record 19 of Set 6 | boddam
# Processing Record 20 of Set 6 | pointe-noire
# Processing Record 21 of Set 6 | saldanha
# Processing Record 22 of Set 6 | mao
# Processing Record 23 of Set 6 | arica
# Processing Record 24 of Set 6 | lagunas
# Processing Record 25 of Set 6 | henties bay
# Processing Record 26 of Set 6 | arroyos y esteros
# Processing Record 27 of Set 6 | chara
# Processing Record 28 of Set 6 | northam
# Processing Record 29 of Set 6 | talah
# 'coord'
# Processing Record 30 of Set 6 | magaria
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | cabo san lucas
# Processing Record 33 of Set 6 | yamethin
# Processing Record 34 of Set 6 | constantine
# Processing Record 35 of Set 6 | myanaung
# Processing Record 36 of Set 6 | palabuhanratu
# 'coord'
# Processing Record 37 of Set 6 | srandakan
# Processing Record 38 of Set 6 | torbay
# Processing Record 39 of Set 6 | antalaha
# Processing Record 40 of Set 6 | bjornevatn
# Processing Record 41 of Set 6 | vanimo
# Processing Record 42 of Set 6 | barranca
# Processing Record 43 of Set 6 | poso
# Processing Record 44 of Set 6 | salinas
# Processing Record 45 of Set 6 | kaitangata
# Processing Record 46 of Set 6 | yarada
# Processing Record 47 of Set 6 | varginha
# Processing Record 48 of Set 6 | louisbourg
# 'coord'
# Processing Record 49 of Set 6 | dunedin
# Processing Record 50 of Set 6 | moquegua
# Processing Record 1 of Set 7 | charters towers
# Processing Record 2 of Set 7 | mitu
# Processing Record 3 of Set 7 | juli
# Processing Record 4 of Set 7 | souillac
# Processing Record 5 of Set 7 | irtyshskiy
# Processing Record 6 of Set 7 | gisborne
# Processing Record 7 of Set 7 | faya
# Processing Record 8 of Set 7 | turka
# Processing Record 9 of Set 7 | gitega
# Processing Record 10 of Set 7 | kidal
# Processing Record 11 of Set 7 | muroto
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | kadykchan
# 'coord'
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | sarankhola
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | napierville
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | pasighat
# Processing Record 20 of Set 7 | buluang
# Processing Record 21 of Set 7 | sabla
# Processing Record 22 of Set 7 | ponta do sol
# Processing Record 23 of Set 7 | gonen
# Processing Record 24 of Set 7 | kloulklubed
# Processing Record 25 of Set 7 | inuvik
# Processing Record 26 of Set 7 | anloga
# Processing Record 27 of Set 7 | azimur
# 'coord'
# Processing Record 28 of Set 7 | kargopol
# Processing Record 29 of Set 7 | thompson
# Processing Record 30 of Set 7 | presidencia roque saenz pena
# Processing Record 31 of Set 7 | saint-pierre
# Processing Record 32 of Set 7 | tonantins
# Processing Record 33 of Set 7 | ghatanji
# Processing Record 34 of Set 7 | pinar del rio
# Processing Record 35 of Set 7 | gat
# Processing Record 36 of Set 7 | okha
# Processing Record 37 of Set 7 | ihlow
# Processing Record 38 of Set 7 | alice springs
# Processing Record 39 of Set 7 | tlaixpan
# Processing Record 40 of Set 7 | komoro
# Processing Record 41 of Set 7 | conde
# Processing Record 42 of Set 7 | mount isa
# Processing Record 43 of Set 7 | solvychegodsk
# Processing Record 44 of Set 7 | cochabamba
# Processing Record 45 of Set 7 | grindavik
# Processing Record 46 of Set 7 | mount gambier
# Processing Record 47 of Set 7 | mangrol
# Processing Record 48 of Set 7 | xinyang
# Processing Record 49 of Set 7 | cap malheureux
# Processing Record 50 of Set 7 | abonnema
# Processing Record 1 of Set 8 | pemberton
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | baruun-urt
# Processing Record 4 of Set 8 | ola
# Processing Record 5 of Set 8 | klaksvik
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | gorontalo
# Processing Record 9 of Set 8 | zaysan
# Processing Record 10 of Set 8 | koslan
# Processing Record 11 of Set 8 | courtenay
# Processing Record 12 of Set 8 | high level
# Processing Record 13 of Set 8 | bartica
# Processing Record 14 of Set 8 | adrar
# Processing Record 15 of Set 8 | vao
# Processing Record 16 of Set 8 | megion
# Processing Record 17 of Set 8 | porto novo
# Processing Record 18 of Set 8 | gigante
# Processing Record 19 of Set 8 | mecca
# Processing Record 20 of Set 8 | axim
# Processing Record 21 of Set 8 | carutapera
# Processing Record 22 of Set 8 | westport
# Processing Record 23 of Set 8 | lompoc
# Processing Record 24 of Set 8 | champerico
# Processing Record 25 of Set 8 | makakilo city
# Processing Record 26 of Set 8 | marfino
# Processing Record 27 of Set 8 | duki
# Processing Record 28 of Set 8 | ruatoria
# 'coord'
# Processing Record 29 of Set 8 | cayenne
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | prince rupert
# Processing Record 32 of Set 8 | bonthe
# Processing Record 33 of Set 8 | pueblo nuevo
# Processing Record 34 of Set 8 | buariki
# 'coord'
# Processing Record 35 of Set 8 | ostrovnoy
# Processing Record 36 of Set 8 | jalu
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | liberal
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | dauphin
# Processing Record 42 of Set 8 | somerville
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | cheney
# Processing Record 45 of Set 8 | aswan
# Processing Record 46 of Set 8 | bambous virieux
# Processing Record 47 of Set 8 | novyy urengoy
# Processing Record 48 of Set 8 | mossendjo
# Processing Record 49 of Set 8 | harjavalta
# Processing Record 50 of Set 8 | san andres
# Processing Record 1 of Set 9 | riohacha
# Processing Record 2 of Set 9 | waikuku
# Processing Record 3 of Set 9 | vernon
# Processing Record 4 of Set 9 | solnechnyy
# Processing Record 5 of Set 9 | el sauzal
# Processing Record 6 of Set 9 | carmo do cajuru
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | kosa
# Processing Record 9 of Set 9 | khombole
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | attawapiskat
# 'coord'
# Processing Record 12 of Set 9 | praia
# Processing Record 13 of Set 9 | alenquer
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | winnemucca
# Processing Record 16 of Set 9 | camacha
# Processing Record 17 of Set 9 | manadhoo
# Processing Record 18 of Set 9 | necochea
# Processing Record 19 of Set 9 | buraydah
# Processing Record 20 of Set 9 | aldan
# Processing Record 21 of Set 9 | martapura
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | kungurtug
# Processing Record 24 of Set 9 | tazovskiy
# Processing Record 25 of Set 9 | siverek
# Processing Record 26 of Set 9 | tezu
# Processing Record 27 of Set 9 | oranjestad
# Processing Record 28 of Set 9 | hit
# Processing Record 29 of Set 9 | doha
# Processing Record 30 of Set 9 | san julian
# Processing Record 31 of Set 9 | smolenka
# Processing Record 32 of Set 9 | ponorogo
# Processing Record 33 of Set 9 | lujan
# Processing Record 34 of Set 9 | hofn
# Processing Record 35 of Set 9 | kahta
# Processing Record 36 of Set 9 | gimli
# Processing Record 37 of Set 9 | kharitonovo
# Processing Record 38 of Set 9 | port keats
# Processing Record 39 of Set 9 | batemans bay
# Processing Record 40 of Set 9 | fortuna
# Processing Record 41 of Set 9 | rio gallegos
# Processing Record 42 of Set 9 | tommot
# Processing Record 43 of Set 9 | atar
# Processing Record 44 of Set 9 | aksu
# Processing Record 45 of Set 9 | shellbrook
# Processing Record 46 of Set 9 | hays
# Processing Record 47 of Set 9 | bama
# Processing Record 48 of Set 9 | nenjiang
# Processing Record 49 of Set 9 | konstantinovka
# Processing Record 50 of Set 9 | sompeta
# Processing Record 1 of Set 10 | kuche
# 'coord'
# Processing Record 2 of Set 10 | santa cruz
# Processing Record 3 of Set 10 | komsomolskiy
# Processing Record 4 of Set 10 | samusu
# 'coord'
# Processing Record 5 of Set 10 | tsiroanomandidy
# Processing Record 6 of Set 10 | zhangye
# Processing Record 7 of Set 10 | okhotsk
# Processing Record 8 of Set 10 | ewo
# Processing Record 9 of Set 10 | dondo
# Processing Record 10 of Set 10 | zimovniki
# Processing Record 11 of Set 10 | chapar
# Processing Record 12 of Set 10 | hay river
# Processing Record 13 of Set 10 | rock sound
# Processing Record 14 of Set 10 | atasu
# Processing Record 15 of Set 10 | kavaratti
# Processing Record 16 of Set 10 | moulins
# Processing Record 17 of Set 10 | thaba-tseka
# Processing Record 18 of Set 10 | rio brilhante
# Processing Record 19 of Set 10 | huallanca
# Processing Record 20 of Set 10 | quiruvilca
# Processing Record 21 of Set 10 | sweetwater
# Processing Record 22 of Set 10 | zhezkazgan
# Processing Record 23 of Set 10 | pemangkat
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | petropavl
# Processing Record 26 of Set 10 | kerteh
# 'coord'
# Processing Record 27 of Set 10 | san quintin
# Processing Record 28 of Set 10 | eyl
# Processing Record 29 of Set 10 | grand-lahou
# Processing Record 30 of Set 10 | port lincoln
# Processing Record 31 of Set 10 | great falls
# Processing Record 32 of Set 10 | havoysund
# Processing Record 33 of Set 10 | noumea
# Processing Record 34 of Set 10 | oktyabrskiy
# Processing Record 35 of Set 10 | helena
# Processing Record 36 of Set 10 | buchanan
# Processing Record 37 of Set 10 | arlit
# Processing Record 38 of Set 10 | leshan
# Processing Record 39 of Set 10 | nerchinskiy zavod
# Processing Record 40 of Set 10 | wilmington
# Processing Record 41 of Set 10 | nalut
# Processing Record 42 of Set 10 | fort-shevchenko
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | aktau
# Processing Record 45 of Set 10 | nha trang
# Processing Record 46 of Set 10 | tandalti
# Processing Record 47 of Set 10 | polson
# Processing Record 48 of Set 10 | ndele
# Processing Record 49 of Set 10 | valparaiso
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | namibe
# Processing Record 2 of Set 11 | koygorodok
# Processing Record 3 of Set 11 | mokhsogollokh
# Processing Record 4 of Set 11 | merauke
# Processing Record 5 of Set 11 | ulladulla
# Processing Record 6 of Set 11 | gadwal
# Processing Record 7 of Set 11 | kirovskiy
# Processing Record 8 of Set 11 | emerald
# Processing Record 9 of Set 11 | nome
# Processing Record 10 of Set 11 | kropotkin
# Processing Record 11 of Set 11 | mayumba
# Processing Record 12 of Set 11 | tsuyama
# Processing Record 13 of Set 11 | seymchan
# Processing Record 14 of Set 11 | mehamn
# Processing Record 15 of Set 11 | dongsheng
# Processing Record 16 of Set 11 | jeremie
# Processing Record 17 of Set 11 | kununurra
# Processing Record 18 of Set 11 | pitimbu
# Processing Record 19 of Set 11 | nouadhibou
# Processing Record 20 of Set 11 | oranjemund
# Processing Record 21 of Set 11 | kuopio
# Processing Record 22 of Set 11 | acajutla
# Processing Record 23 of Set 11 | noyabrsk
# Processing Record 24 of Set 11 | ivanteyevka
# Processing Record 25 of Set 11 | mishkino
# Processing Record 26 of Set 11 | menongue
# Processing Record 27 of Set 11 | gwadar
# Processing Record 28 of Set 11 | sakakah
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | maine-soroa
# Processing Record 31 of Set 11 | shimoda
# Processing Record 32 of Set 11 | masjed-e soleyman
# 'coord'
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | porto walter
# Processing Record 35 of Set 11 | bud
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | vila
# Processing Record 38 of Set 11 | bethel
# Processing Record 39 of Set 11 | denpasar
# Processing Record 40 of Set 11 | santeramo in colle
# Processing Record 41 of Set 11 | umzimvubu
# 'coord'
# Processing Record 42 of Set 11 | baykit
# Processing Record 43 of Set 11 | naron
# Processing Record 44 of Set 11 | nyurba
# Processing Record 45 of Set 11 | sivaki
# Processing Record 46 of Set 11 | tikrit
# Processing Record 47 of Set 11 | lanivtsi
# Processing Record 48 of Set 11 | umm ruwabah
# 'coord'
# Processing Record 49 of Set 11 | qasigiannguit
# Processing Record 50 of Set 11 | lososina
# Processing Record 1 of Set 12 | isangel
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | kuli
# Processing Record 4 of Set 12 | derzhavinsk
# Processing Record 5 of Set 12 | kupang
# Processing Record 6 of Set 12 | cape canaveral
# Processing Record 7 of Set 12 | san lorenzo
# Processing Record 8 of Set 12 | acarau
# Processing Record 9 of Set 12 | spasskoye
# Processing Record 10 of Set 12 | tabou
# Processing Record 11 of Set 12 | nara
# Processing Record 12 of Set 12 | ukiah
# Processing Record 13 of Set 12 | temyasovo
# Processing Record 14 of Set 12 | tarudant
# 'coord'
# Processing Record 15 of Set 12 | polonne
# Processing Record 16 of Set 12 | sibu
# Processing Record 17 of Set 12 | seydi
# Processing Record 18 of Set 12 | bargal
# 'coord'
# Processing Record 19 of Set 12 | bababe
# 'coord'
# Processing Record 20 of Set 12 | comodoro rivadavia
# Processing Record 21 of Set 12 | banda aceh
# Processing Record 22 of Set 12 | kieta
# Processing Record 23 of Set 12 | bangkal
# Processing Record 24 of Set 12 | grand-santi
# Processing Record 25 of Set 12 | half moon bay
# Processing Record 26 of Set 12 | lazi
# Processing Record 27 of Set 12 | la libertad
# Processing Record 28 of Set 12 | mahibadhoo
# Processing Record 29 of Set 12 | beloha
# Processing Record 30 of Set 12 | krasnyy kholm
# Processing Record 31 of Set 12 | escanaba
# Processing Record 32 of Set 12 | kashi
# Processing Record 33 of Set 12 | pangoa
# Processing Record 34 of Set 12 | mahbubnagar
# Processing Record 35 of Set 12 | pinsk
# Processing Record 36 of Set 12 | port pirie
# Processing Record 37 of Set 12 | gotsu
# Processing Record 38 of Set 12 | santa cruz cabralia
# Processing Record 39 of Set 12 | ekibastuz
# Processing Record 40 of Set 12 | huamuxtitlan
# Processing Record 41 of Set 12 | kalmunai
# Processing Record 42 of Set 12 | carora
# Processing Record 43 of Set 12 | san vicente
# Processing Record 44 of Set 12 | melo
# Processing Record 45 of Set 12 | palora
# Processing Record 46 of Set 12 | vardo
# Processing Record 47 of Set 12 | nileshwar
# Processing Record 48 of Set 12 | prado
# Processing Record 49 of Set 12 | naryan-mar
# Processing Record 50 of Set 12 | forest hills
# Processing Record 1 of Set 13 | sao joao da barra
# Processing Record 2 of Set 13 | berlevag
# Processing Record 3 of Set 13 | manavgat
# Processing Record 4 of Set 13 | aksarka
# Processing Record 5 of Set 13 | kenmore
# Processing Record 6 of Set 13 | luangwa
# Processing Record 7 of Set 13 | biltine
# Processing Record 8 of Set 13 | warqla
# 'coord'
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | narsaq
# Processing Record 11 of Set 13 | tawkar
# 'coord'
# Processing Record 12 of Set 13 | urubamba
# Processing Record 13 of Set 13 | bengbu
# Processing Record 14 of Set 13 | ordubad
# Processing Record 15 of Set 13 | beira
# Processing Record 16 of Set 13 | mumford
# Processing Record 17 of Set 13 | viligili
# 'coord'
# Processing Record 18 of Set 13 | shubarshi
# Processing Record 19 of Set 13 | alofi
# Processing Record 20 of Set 13 | medea
# Processing Record 21 of Set 13 | kegums
# Processing Record 22 of Set 13 | araguatins
# 'coord'
# Processing Record 23 of Set 13 | zabaykalsk
# Processing Record 24 of Set 13 | luang prabang
# Processing Record 25 of Set 13 | newport
# Processing Record 26 of Set 13 | supe
# Processing Record 27 of Set 13 | galiwinku
# 'coord'
# Processing Record 28 of Set 13 | dauriya
# Processing Record 29 of Set 13 | lithakia
# Processing Record 30 of Set 13 | bereda
# Processing Record 31 of Set 13 | dengzhou
# Processing Record 32 of Set 13 | fort saint james
# Processing Record 33 of Set 13 | bubaque
# Processing Record 34 of Set 13 | lasa
# Processing Record 35 of Set 13 | namatanai
# Processing Record 36 of Set 13 | pekalongan
# Processing Record 37 of Set 13 | alugan
# Processing Record 38 of Set 13 | zolotinka
# 'coord'
# Processing Record 39 of Set 13 | ratnagiri
# Processing Record 40 of Set 13 | brigantine
# Processing Record 41 of Set 13 | adamas
# Processing Record 42 of Set 13 | khasan
# Processing Record 43 of Set 13 | ancud
# Processing Record 44 of Set 13 | boca do acre
# Processing Record 45 of Set 13 | igarka
# Processing Record 46 of Set 13 | puerto escondido
# Processing Record 47 of Set 13 | sao gabriel da cachoeira
# Processing Record 48 of Set 13 | korem
# Processing Record 49 of Set 13 | cairns
# Processing Record 50 of Set 13 | ulaanbaatar
# Processing Record 1 of Set 14 | katunino
# Processing Record 2 of Set 14 | pimentel
# Processing Record 3 of Set 14 | ijaki
# 'coord'
# Processing Record 4 of Set 14 | hachinohe
# Processing Record 5 of Set 14 | viransehir
# Processing Record 6 of Set 14 | vila franca do campo
# Processing Record 7 of Set 14 | kailua
# Processing Record 8 of Set 14 | nova granada
# Processing Record 9 of Set 14 | cantanhede
# Processing Record 10 of Set 14 | matara
# Processing Record 11 of Set 14 | chapais
# Processing Record 12 of Set 14 | abaza
# Processing Record 13 of Set 14 | gari
# Processing Record 14 of Set 14 | itupiranga
# Processing Record 15 of Set 14 | broome
# Processing Record 16 of Set 14 | leningradskiy
# Processing Record 17 of Set 14 | rockport
# Processing Record 18 of Set 14 | svirstroy
# Processing Record 19 of Set 14 | hinton
# Processing Record 20 of Set 14 | vitina
# Processing Record 21 of Set 14 | ulety
# Processing Record 22 of Set 14 | barra patuca
# Processing Record 23 of Set 14 | waterloo
# Processing Record 24 of Set 14 | kurilsk
# Processing Record 25 of Set 14 | buncrana
# Processing Record 26 of Set 14 | bandrele
# Processing Record 27 of Set 14 | shiyan
# Processing Record 28 of Set 14 | svetlaya
# Processing Record 29 of Set 14 | chuguyevka
# Processing Record 30 of Set 14 | victor harbor
# Processing Record 31 of Set 14 | hambantota
# Processing Record 32 of Set 14 | zhitikara
# 'coord'
# Processing Record 33 of Set 14 | paita
# Processing Record 34 of Set 14 | enid
# Processing Record 35 of Set 14 | kangaatsiaq
# Processing Record 36 of Set 14 | tutoia
# Processing Record 37 of Set 14 | skegness
# Processing Record 38 of Set 14 | vestmannaeyjar
# Processing Record 39 of Set 14 | mahajanga
# Processing Record 40 of Set 14 | wulanhaote
# 'coord'
# Processing Record 41 of Set 14 | aktash
# Processing Record 42 of Set 14 | bage
# Processing Record 43 of Set 14 | saint anthony
# Processing Record 44 of Set 14 | andenes
# Processing Record 45 of Set 14 | tateyama
# Processing Record 46 of Set 14 | petkovci
# Processing Record 47 of Set 14 | medveda
# Processing Record 48 of Set 14 | itarema
# Processing Record 49 of Set 14 | utiroa
# 'coord'
# Processing Record 50 of Set 14 | uusikaupunki
# Processing Record 1 of Set 15 | czersk
# Processing Record 2 of Set 15 | burica
# 'coord'
# Processing Record 3 of Set 15 | verkhoyansk
# Processing Record 4 of Set 15 | mchinji
# Processing Record 5 of Set 15 | ayolas
# Processing Record 6 of Set 15 | new iberia
# Processing Record 7 of Set 15 | diego de almagro
# Processing Record 8 of Set 15 | washougal
# Processing Record 9 of Set 15 | barawe
# 'coord'
# Processing Record 10 of Set 15 | jiaocheng
# Processing Record 11 of Set 15 | suntar
# Processing Record 12 of Set 15 | ksenyevka
# 'coord'
# Processing Record 13 of Set 15 | lianzhou
# Processing Record 14 of Set 15 | chiredzi
# Processing Record 15 of Set 15 | castlemaine
# Processing Record 16 of Set 15 | butembo
# Processing Record 17 of Set 15 | brae
# Processing Record 18 of Set 15 | saint-francois
# Processing Record 19 of Set 15 | fairbanks
# Processing Record 20 of Set 15 | broken hill
# Processing Record 21 of Set 15 | skibbereen
# Processing Record 22 of Set 15 | liku
# Processing Record 23 of Set 15 | chandbali
# Processing Record 24 of Set 15 | meyungs
# 'coord'
# Processing Record 25 of Set 15 | yegros
# Processing Record 26 of Set 15 | surgut
# Processing Record 27 of Set 15 | borsa
# Processing Record 28 of Set 15 | fort nelson
# Processing Record 29 of Set 15 | auki
# Processing Record 30 of Set 15 | agva
# 'coord'
# Processing Record 31 of Set 15 | wuda
# Processing Record 32 of Set 15 | nueva granada
# Processing Record 33 of Set 15 | sterling
# Processing Record 34 of Set 15 | marystown
# Processing Record 35 of Set 15 | avera
# Processing Record 36 of Set 15 | calvia
# Processing Record 37 of Set 15 | mabaruma
# Processing Record 38 of Set 15 | fuxin
# Processing Record 39 of Set 15 | yantal
# Processing Record 40 of Set 15 | sao sebastiao
# Processing Record 41 of Set 15 | gemena
# Processing Record 42 of Set 15 | polessk
# Processing Record 43 of Set 15 | orange
# Processing Record 44 of Set 15 | puri
# Processing Record 45 of Set 15 | tyup
# Processing Record 46 of Set 15 | dinsor
# 'coord'
# Processing Record 47 of Set 15 | kozulka
# Processing Record 48 of Set 15 | sisimiut
# Processing Record 49 of Set 15 | bodden town
# Processing Record 50 of Set 15 | hollins
# Processing Record 1 of Set 16 | murovani kurylivtsi
# Processing Record 2 of Set 16 | lata
# Processing Record 3 of Set 16 | lock haven
# Processing Record 4 of Set 16 | candido de abreu
# Processing Record 5 of Set 16 | khandbari
# Processing Record 6 of Set 16 | takoradi
# Processing Record 7 of Set 16 | hyeres
# ------------------------
#  Data Retrieval Complete
# ------------------------

# %%
weather_database_df = pd.DataFrame(city_data)
weather_database_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Barrow      US  71.2906 -156.7887     35.62        93
# 1              Albany      US  42.6001  -73.9662     73.45        76
# 2             Sawakin      SD  19.1059   37.3321     92.89        53
# 3             Rikitea      PF -23.1203 -134.9692     72.91        74
# 4            Khatanga      RU  71.9667  102.5000     45.32        58
# ..                ...     ...      ...       ...       ...       ...
# 688        Lock Haven      US  41.1370  -77.4469     77.70        77
# 689  Candido De Abreu      BR -24.5669  -51.3333     44.40        75
# 690         Khandbari      NP  27.3747   87.2039     76.10        86
# 691          Takoradi      GH   4.8845   -1.7554     74.12        90
# 692            Hyeres      FR  43.1167    6.1167     74.41        53
#
#      Cloudiness  Wind Speed Current Description
# 0           100        9.22                mist
# 1            40        3.09    scattered clouds
# 2            14        3.22          few clouds
# 3            44        8.48    scattered clouds
# 4           100        7.56     overcast clouds
# ..          ...         ...                 ...
# 688          99        2.26     overcast clouds
# 689         100        5.70     overcast clouds
# 690          77        0.29       broken clouds
# 691         100       10.16     overcast clouds
# 692           0        8.05           clear sky
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
